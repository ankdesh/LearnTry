# %%
# Top Matter
import numpy as np
import matplotlib.pyplot as plt
import sys

# Required for plotting in WSL
import matplotlib
matplotlib.use('Agg')

from utils.methods import format_analysis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 import matplotlib
#       8 matplotlib.use('Agg')
# ---> 10 from utils.methods import format_analysis
#
# File ~/explore/LearnTry/eda/spice/ngspice-examples/yt-tutorial-examples/utils.py:5
#       2 import os
#       3 from typing import List, Dict, Optional
# ----> 5 import PySpice
#       6 from PySpice.Spice.Netlist import Circuit
#      10 def cast_waveform(waveform) -> np.ndarray|float:
#
# ModuleNotFoundError: No module named 'PySpice'

# %%
import PySpice
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import PySpice
#
# ModuleNotFoundError: No module named 'PySpice'
